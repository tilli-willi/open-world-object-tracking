# %%
from sort import Sort
from pathlib import Path
import argparse
from copy import deepcopy
import json
import os
import os.path as osp
from pathlib import Path
import time
from typing import Tuple

import numpy as np
from PIL import Image

from pycocotools import mask as cocomask

# %%
# Arguments
max_age = 30

# %%
def rle_ann_to_mask(rle: str, image_size: Tuple[int, int]) -> np.ndarray:
    return cocomask.decode({
        "size": image_size,
        "counts": rle.encode("utf-8")
    }).astype(bool)
    
def calculate_iou(box1, box2):
    # Coordinates of the intersection rectangle
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    
    # Intersection area
    intersection_width = max(0, x2 - x1)
    intersection_height = max(0, y2 - y1)
    intersection_area = intersection_width * intersection_height
    
    # Areas of both rectangles
    area_box1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area_box2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    
    # Union area
    union_area = area_box1 + area_box2 - intersection_area
    
    # IoU calculation
    iou = intersection_area / union_area if union_area > 0 else 0
    return iou

def find_box_with_max_iou(boxes, target_box):
    max_iou = 0
    max_index = -1
    for i, box in enumerate(boxes):
        if box is None:
            continue
        iou = calculate_iou(box, target_box)
        if iou > max_iou:
            max_iou = iou
            max_index = i
    return max_index, max_iou

# %%
boxes_masks_path = "/home/uig93971/src/data/street_obstacle_sequences/detections/boxes_masks"
boxes_masks_path = Path(boxes_masks_path)
heatmaps_path = "/home/uig93971/src/data/street_obstacle_sequences/detections/heatmaps"
track_masks_path = "/home/uig93971/src/data/street_obstacle_sequences/detections/ood_prediction_tracked"
video_id = None
video_ids = [video_id] if video_id is not None else [os.path.basename(str(f)) for f in boxes_masks_path.iterdir() if f.is_dir()]

videos_processed = 0
videos_total = len(video_ids)
inference_start_time = time.time()

sort_tracker = Sort(max_age=max_age)

for video_id in video_ids:
    frame_data_paths = [str(f) for f in (boxes_masks_path / video_id).iterdir() if f.is_file()]    
    frame_data_paths.sort()
    
    Path(osp.join(track_masks_path, video_id)).mkdir(parents=True, exist_ok=True)
    
    for frame_id, frame_path in enumerate(frame_data_paths, 1):
        with open(frame_path, "r") as f:
            frame_data = json.load(f)
        boxes = frame_data["boxes"]
        scores = frame_data["scores"]
        masks = frame_data["masks"]
        dets_to_feed = []
        for score, box, enc_mask in zip(scores, boxes, masks):
            mask = rle_ann_to_mask(enc_mask, (1080, 1920))
            if np.sum(mask) < 100:
                continue
            dets_to_feed.append(np.concatenate([box, [score]]))
        dets_to_feed = np.array(dets_to_feed)
        if len(dets_to_feed > 0):
            trackers = sort_tracker.update(dets_to_feed)
        else:
            trackers = sort_tracker.update()
        
        final_track_mask = np.zeros((1080, 1920), dtype=np.uint16)
        for tracker in trackers:
            tr_id = tracker[4]
            tr_box = tracker[:4]
            box_index, box_iou = find_box_with_max_iou(boxes, tr_box)
            if box_iou < 0.5:
                print(f"Box IoU is less than 0.5: {box_iou}")
            mask = rle_ann_to_mask(masks[box_index], (1080, 1920))
            final_track_mask[mask] = tr_id
            
        np.save(osp.join(track_masks_path, video_id, osp.splitext(os.path.basename(frame_path))[0] + ".npy"), final_track_mask)
    
    videos_processed += 1
    print(f"Processed videos {videos_processed}/{videos_total}")
    print(f"Time passed: {(time.time() - inference_start_time):.4f} seconds, Avg time per video: {(time.time() - inference_start_time) / videos_processed:.4f} seconds")
# Out:
# Box IoU is less than 0.5: 0.38895432246433936
# Box IoU is less than 0.5: 0.46495470712962117
# Box IoU is less than 0.5: 0.48758612688749264
# Box IoU is less than 0.5: 0.4804536747233322
# Box IoU is less than 0.5: 0.4329689682461474
# Box IoU is less than 0.5: 0.4565374858821196
# Box IoU is less than 0.5: 0.48174447734601017
# Box IoU is less than 0.5: 0.4904056580557013
# Box IoU is less than 0.5: 0.41511312642582165
# Box IoU is less than 0.5: 0.48903275204728364
# Box IoU is less than 0.5: 0.43893915016897717
# Box IoU is less than 0.5: 0.49440959926805306
# Box IoU is less than 0.5: 0.4901235966552905
# Box IoU is less than 0.5: 0.3937044213068359
# Box IoU is less than 0.5: 0.41988963919403505
# Box IoU is less than 0.5: 0.3920225790912589
# Box IoU is less than 0.5: 0.4960182495734719
# Processed videos 1/20
# Time passed: 63.7069 seconds, Avg time per video: 63.7069 seconds
# Box IoU is less than 0.5: 0.48046501078619147
# Box IoU is less than 0.5: 0.46647350531282306
# Box IoU is less than 0.5: 0.42815739621629123
# Box IoU is less than 0.5: 0.4259415960896838
# Box IoU is less than 0.5: 0.38194559195297023
# Box IoU is less than 0.5: 0.4429242967756509
# Box IoU is less than 0.5: 0.49416881277098595
# Box IoU is less than 0.5: 0.4541270834407047
# Box IoU is less than 0.5: 0.42041464918290244
# Box IoU is less than 0.5: 0.4340496993424956
# Box IoU is less than 0.5: 0.47977603950031106
# Box IoU is less than 0.5: 0.39038486963033137
# Box IoU is less than 0.5: 0.47666407510405434
# Box IoU is less than 0.5: 0.4348491793206608
# Box IoU is less than 0.5: 0.3782925238558166
# Box IoU is less than 0.5: 0.4773612026059734
# Box IoU is less than 0.5: 0.404278443868077
# Box IoU is less than 0.5: 0.4578260743863073
# Box IoU is less than 0.5: 0.42234635860416697
# Box IoU is less than 0.5: 0.41277093015165
# Box IoU is less than 0.5: 0.43742935564921487
# Processed videos 2/20
# Time passed: 120.2697 seconds, Avg time per video: 60.1348 seconds
# Box IoU is less than 0.5: 0.38486296118376134
# Box IoU is less than 0.5: 0.4350419514240503
# Box IoU is less than 0.5: 0.3967855162810591
# Box IoU is less than 0.5: 0.49423630086931686
# Box IoU is less than 0.5: 0.4413860620595717
# Box IoU is less than 0.5: 0.4065901005067455
# Box IoU is less than 0.5: 0.4827064030332245
# Box IoU is less than 0.5: 0.43659714663141147
# Box IoU is less than 0.5: 0.4381532357523442
# Box IoU is less than 0.5: 0.485191847672961
# Box IoU is less than 0.5: 0.41961161294370053
# Box IoU is less than 0.5: 0.44533112532359087
# Box IoU is less than 0.5: 0.48619407069573856
# Box IoU is less than 0.5: 0.41723081331415257
# Box IoU is less than 0.5: 0.48610591052371627
# Box IoU is less than 0.5: 0.40785659456440904
# Box IoU is less than 0.5: 0.4865757221109406
# Box IoU is less than 0.5: 0.4525700025330168
# Box IoU is less than 0.5: 0.4879946517171214
# Box IoU is less than 0.5: 0.4394368052500818
# Box IoU is less than 0.5: 0.38364854276904514
# Box IoU is less than 0.5: 0.4778026142938262
# Box IoU is less than 0.5: 0.43338654048015696
# Box IoU is less than 0.5: 0.4958485971162205
# Processed videos 3/20
# Time passed: 189.6097 seconds, Avg time per video: 63.2032 seconds
# Box IoU is less than 0.5: 0.4148464932928205
# Box IoU is less than 0.5: 0.48882701267738016
# Box IoU is less than 0.5: 0.4648525674162523
# Box IoU is less than 0.5: 0.440247006775441
# Box IoU is less than 0.5: 0.4408376281490318
# Box IoU is less than 0.5: 0.4989695106892089
# Box IoU is less than 0.5: 0.47892199778391825
# Box IoU is less than 0.5: 0.4315399455034521
# Processed videos 4/20
# Time passed: 237.9938 seconds, Avg time per video: 59.4985 seconds
# Box IoU is less than 0.5: 0.46719421180304216
# Box IoU is less than 0.5: 0.48319894982680556
# Box IoU is less than 0.5: 0.4926768937029588
# Box IoU is less than 0.5: 0.45765235517612607
# Processed videos 5/20
# Time passed: 275.0641 seconds, Avg time per video: 55.0128 seconds
# Box IoU is less than 0.5: 0.4534197624646198
# Box IoU is less than 0.5: 0.4341302100718291
# Box IoU is less than 0.5: 0.4155384914150431
# Box IoU is less than 0.5: 0.42259441973796935
# Box IoU is less than 0.5: 0.4697058437942339
# Processed videos 6/20
# Time passed: 303.3105 seconds, Avg time per video: 50.5518 seconds
# Box IoU is less than 0.5: 0.4826492438688518
# Box IoU is less than 0.5: 0.4901897020614029
# Box IoU is less than 0.5: 0.45290756230572166
# Box IoU is less than 0.5: 0.4906618031549811
# Box IoU is less than 0.5: 0.40780556656395
# Processed videos 7/20
# Time passed: 337.1625 seconds, Avg time per video: 48.1661 seconds
# Box IoU is less than 0.5: 0.4522234222759311
# Box IoU is less than 0.5: 0.48374853404925167
# Box IoU is less than 0.5: 0.4991241369383306
# Box IoU is less than 0.5: 0.46791651617821345
# Box IoU is less than 0.5: 0.4092449237712522
# Box IoU is less than 0.5: 0.45737594873116594
# Box IoU is less than 0.5: 0.4424018487838246
# Processed videos 8/20
# Time passed: 371.9744 seconds, Avg time per video: 46.4968 seconds
# Box IoU is less than 0.5: 0.45623686786889056
# Box IoU is less than 0.5: 0.4570825720603503
# Box IoU is less than 0.5: 0.44034905078001013
# Box IoU is less than 0.5: 0.4587968046772106
# Box IoU is less than 0.5: 0.44505139193825405
# Box IoU is less than 0.5: 0.408450712841518
# Box IoU is less than 0.5: 0.4975227305781048
# Box IoU is less than 0.5: 0.4367944130711948
# Box IoU is less than 0.5: 0.44506514752916615
# Box IoU is less than 0.5: 0.4523452185287445
# Box IoU is less than 0.5: 0.46365949630468417
# Box IoU is less than 0.5: 0.4403360612023001
# Box IoU is less than 0.5: 0.493923827980711
# Box IoU is less than 0.5: 0.49496968230992877
# Box IoU is less than 0.5: 0.4841785313554579
# Box IoU is less than 0.5: 0.48062793981512864
# Box IoU is less than 0.5: 0.4146139887544448
# Box IoU is less than 0.5: 0.49645300557964966
# Box IoU is less than 0.5: 0.4494613247142087
# Box IoU is less than 0.5: 0.44815445431107026
# Box IoU is less than 0.5: 0.47989237655414646
# Processed videos 9/20
# Time passed: 460.7426 seconds, Avg time per video: 51.1936 seconds
# Box IoU is less than 0.5: 0.4281948197937823
# Box IoU is less than 0.5: 0.4959255669042743
# Box IoU is less than 0.5: 0.4106995959772601
# Box IoU is less than 0.5: 0.43109969606793647
# Box IoU is less than 0.5: 0.40525608370804184
# Box IoU is less than 0.5: 0.4958371977811048
# Box IoU is less than 0.5: 0.46596505553178713
# Box IoU is less than 0.5: 0.4555725037452382
# Box IoU is less than 0.5: 0.4553555317193927
# Box IoU is less than 0.5: 0.4543410250913986
# Box IoU is less than 0.5: 0.4816189290210995
# Box IoU is less than 0.5: 0.48072099466147833
# Box IoU is less than 0.5: 0.4853720435035145
# Box IoU is less than 0.5: 0.49105238090971226
# Box IoU is less than 0.5: 0.47993458946297324
# Box IoU is less than 0.5: 0.48346383360898143
# Box IoU is less than 0.5: 0.48889429052802497
# Box IoU is less than 0.5: 0.4811270706695734
# Processed videos 10/20
# Time passed: 549.3621 seconds, Avg time per video: 54.9362 seconds
# Box IoU is less than 0.5: 0.49152843618961545
# Box IoU is less than 0.5: 0.48841346610275427
# Box IoU is less than 0.5: 0.4611754906251805
# Box IoU is less than 0.5: 0.4583845015720943
# Box IoU is less than 0.5: 0.4538249214311763
# Processed videos 11/20
# Time passed: 594.6523 seconds, Avg time per video: 54.0593 seconds
# Box IoU is less than 0.5: 0.46999122454115155
# Box IoU is less than 0.5: 0.46659046954102884
# Box IoU is less than 0.5: 0.3904234521254054
# Box IoU is less than 0.5: 0.41494659119971194
# Box IoU is less than 0.5: 0.4883501383674137
# Box IoU is less than 0.5: 0.4924239366191113
# Box IoU is less than 0.5: 0.44477960669345207
# Box IoU is less than 0.5: 0.47888290666966865
# Box IoU is less than 0.5: 0.49087424855079265
# Box IoU is less than 0.5: 0.491428340693318
# Box IoU is less than 0.5: 0.48988071469421296
# Box IoU is less than 0.5: 0.39286833847611224
# Box IoU is less than 0.5: 0.41823041397745353
# Box IoU is less than 0.5: 0.4748845318334388
# Box IoU is less than 0.5: 0.46077880433775925
# Box IoU is less than 0.5: 0.45433764817459316
# Box IoU is less than 0.5: 0.47005575436278596
# Box IoU is less than 0.5: 0.4837044902615879
# Box IoU is less than 0.5: 0.43054152534193274
# Box IoU is less than 0.5: 0.48108893813241754
# Processed videos 12/20
# Time passed: 679.7800 seconds, Avg time per video: 56.6483 seconds
# Box IoU is less than 0.5: 0.49136112610631233
# Box IoU is less than 0.5: 0.41457343154102866
# Processed videos 13/20
# Time passed: 689.1364 seconds, Avg time per video: 53.0105 seconds
# Box IoU is less than 0.5: 0.4602032657870891
# Box IoU is less than 0.5: 0.4914660896046829
# Box IoU is less than 0.5: 0.4131935163328204
# Box IoU is less than 0.5: 0.4652650441038502
# Box IoU is less than 0.5: 0.4311805843576769
# Box IoU is less than 0.5: 0.3789705099282731
# Box IoU is less than 0.5: 0.4755550942759879
# Box IoU is less than 0.5: 0.4551707384135657
# Box IoU is less than 0.5: 0.4921931833722617
# Box IoU is less than 0.5: 0.4502252909141175
# Box IoU is less than 0.5: 0.46444527311994815
# Box IoU is less than 0.5: 0.3995088227137338
# Processed videos 14/20
# Time passed: 769.0436 seconds, Avg time per video: 54.9317 seconds
# Box IoU is less than 0.5: 0.4905256163234238
# Box IoU is less than 0.5: 0.47967643063893195
# Box IoU is less than 0.5: 0.3971957756695543
# Box IoU is less than 0.5: 0.4564479240688588
# Box IoU is less than 0.5: 0.39418920450862316
# Box IoU is less than 0.5: 0.4600490583458194
# Box IoU is less than 0.5: 0.4963867195746826
# Box IoU is less than 0.5: 0.48520833395789376
# Processed videos 15/20
# Time passed: 832.6120 seconds, Avg time per video: 55.5075 seconds
# Box IoU is less than 0.5: 0.4338815849493517
# Box IoU is less than 0.5: 0.49724989233111155
# Box IoU is less than 0.5: 0.466719325510873
# Box IoU is less than 0.5: 0.4617258474605717
# Box IoU is less than 0.5: 0.46096166363774727
# Box IoU is less than 0.5: 0.43896731128588556
# Box IoU is less than 0.5: 0.49639872010139113
# Box IoU is less than 0.5: 0.4717653102505269
# Box IoU is less than 0.5: 0.4670510616931435
# Box IoU is less than 0.5: 0.40469652666203665
# Box IoU is less than 0.5: 0.4272755667878785
# Box IoU is less than 0.5: 0.44071968515474497
# Box IoU is less than 0.5: 0.48016687189443724
# Box IoU is less than 0.5: 0.45959877875082467
# Box IoU is less than 0.5: 0.4419913016176895
# Box IoU is less than 0.5: 0.4861377352879525
# Box IoU is less than 0.5: 0.47218178895953666
# Box IoU is less than 0.5: 0.48785064083302787
# Box IoU is less than 0.5: 0.4548710098841593
# Box IoU is less than 0.5: 0.4417118896415823
# Box IoU is less than 0.5: 0.4448518226665045
# Box IoU is less than 0.5: 0.3661879971469612
# Box IoU is less than 0.5: 0.49583819377866895
# Processed videos 16/20
# Time passed: 932.8033 seconds, Avg time per video: 58.3002 seconds
# Box IoU is less than 0.5: 0.4703204217268266
# Box IoU is less than 0.5: 0.3817827759264622
# Box IoU is less than 0.5: 0.4490954223202966
# Box IoU is less than 0.5: 0.4480987789457588
# Box IoU is less than 0.5: 0.4428834367086711
# Box IoU is less than 0.5: 0.49972124797994494
# Box IoU is less than 0.5: 0.4763465318100145
# Box IoU is less than 0.5: 0.49396153775972856
# Box IoU is less than 0.5: 0.37302466820259117
# Box IoU is less than 0.5: 0.41021959108756595
# Box IoU is less than 0.5: 0.47754153420031825
# Processed videos 17/20
# Time passed: 994.9437 seconds, Avg time per video: 58.5261 seconds
# Box IoU is less than 0.5: 0.4814150990308548
# Box IoU is less than 0.5: 0.45464912691959203
# Box IoU is less than 0.5: 0.4979313750282936
# Box IoU is less than 0.5: 0.417647168010747
# Processed videos 18/20
# Time passed: 1027.6630 seconds, Avg time per video: 57.0924 seconds
# Box IoU is less than 0.5: 0.42869038146656663
# Box IoU is less than 0.5: 0.4507434106508749
# Box IoU is less than 0.5: 0.45587120109235
# Box IoU is less than 0.5: 0.47006456236956434
# Box IoU is less than 0.5: 0.4902443233569177
# Box IoU is less than 0.5: 0.40775047670314374
# Box IoU is less than 0.5: 0.4992079231342246
# Box IoU is less than 0.5: 0.45517979707017947
# Box IoU is less than 0.5: 0.4861803013881719
# Box IoU is less than 0.5: 0.4926496635121556
# Box IoU is less than 0.5: 0.4880840495515142
# Processed videos 19/20
# Time passed: 1094.7965 seconds, Avg time per video: 57.6209 seconds
# Box IoU is less than 0.5: 0.41081287197041055
# Box IoU is less than 0.5: 0.47974175618212545
# Box IoU is less than 0.5: 0.4385105589864422
# Box IoU is less than 0.5: 0.4883422701542436
# Box IoU is less than 0.5: 0.49395690057097014
# Box IoU is less than 0.5: 0.4930903269394012
# Box IoU is less than 0.5: 0.4719988940525385
# Box IoU is less than 0.5: 0.4616184224411281
# Box IoU is less than 0.5: 0.4371691745382934
# Box IoU is less than 0.5: 0.3944325793756433
# Box IoU is less than 0.5: 0.4680110108069518
# Box IoU is less than 0.5: 0.40007937278813244
# Box IoU is less than 0.5: 0.4137588197407154
# Box IoU is less than 0.5: 0.41889250891334434
# Box IoU is less than 0.5: 0.4520026805397079
# Box IoU is less than 0.5: 0.3893680009857729
# Processed videos 20/20
# Time passed: 1177.6883 seconds, Avg time per video: 58.8844 seconds

# %%
enc_mask = "Q\\SQ14`Q15L4N2O0O1O100O1O1O10000O10000000001O00000000001O00000000001O000000001O0001O0001O0001O00000010O0001O0000001O001O001N101O1O1O001O1O1O1O1N2O3Lcgjk0"
np.sum(rle_ann_to_mask(enc_mask, (1080, 1920)))
# Out:
# 1425

# %%
np.concatenate([[1, 2, 3, 4], [100]])
# Out:
# array([  1,   2,   3,   4, 100])
